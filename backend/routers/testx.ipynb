# %%
# %pip install xkd
# Out:
# Collecting xkd
#   Downloading xkd-0.1.8-py3-none-any.whl.metadata (3.7 kB)
# Collecting panda3d>=1.10.15 (from xkd)
#   Downloading panda3d-1.10.16-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.3 kB)
# Collecting panda3d-gltf>=1.2.0 (from xkd)
#   Downloading panda3d_gltf-1.3.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting panda3d-simplepbr>=0.6 (from panda3d-gltf>=1.2.0->xkd)
#   Downloading panda3d_simplepbr-0.13.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing_extensions~=4.7 in /Users/chris/Documents/GitHub/TrackATeam4Project/.venv/lib/python3.13/site-packages (from panda3d-simplepbr>=0.6->panda3d-gltf>=1.2.0->xkd) (4.15.0)
# Downloading xkd-0.1.8-py3-none-any.whl (3.4 kB)
# Downloading panda3d-1.10.16-cp313-cp313-macosx_11_0_universal2.whl (120.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 MB 7.9 MB/s  0:00:15m0:00:0100:01
# Downloading panda3d_gltf-1.3.0-py3-none-any.whl (27 kB)
# Downloading panda3d_simplepbr-0.13.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: panda3d, panda3d-simplepbr, panda3d-gltf, xkd
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [xkd]1/4 [panda3d-simplepbr]
# Successfully installed panda3d-1.10.16 panda3d-gltf-1.3.0 panda3d-simplepbr-0.13.1 xkd-0.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the client
from xdk import Client
# Replace with your actual Bearer Token
client = Client(bearer_token="YOUR_BEARER_TOKEN_HERE")
# Fetch recent Posts mentioning "api"
# search_recent returns an Iterator, so iterate over it
for page in client.posts.search_recent(query="first", max_results=10):
    if page.data and len(page.data) > 0:
        # Access first Post - Pydantic models support both attribute and dict access
        first_post = page.data[0]
        post_text = first_post.text if hasattr(first_post, 'text') else first_post.get('text', '')
        print(f"Latest Post: {post_text}")
        break
    else:
        print("No Posts found.")
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Import the client
# ----> 2 from xdk import Client
#       3 # Replace with your actual Bearer Token
#       4 client = Client(bearer_token="YOUR_BEARER_TOKEN_HERE")
#
# ModuleNotFoundError: No module named 'xdk'
